# %% [markdown]
# # TBL Model Development: Random Forest Regression

# %%
# imports
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV, train_test_split, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from joblib import Parallel, delayed

# %%
# Processing Data Function (switching to using radius)

def read_and_process_data(directory_path):
    data_frames = []
    columns_to_extract = ['radius_X', 'radius_Y', 'radius_Z', 'radius_Ox', 'radius_Oy', 'radius_Oz', 'Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz']

    # Assuming each cycle has exactly 356 data points
    total_data_points = 356

    for file_name in os.listdir(directory_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(directory_path, file_name)
            participant = int(os.path.basename(file_path).split('_')[0])
            cycle_id = os.path.basename(file_path).split('_')[1].split('.')[0]  # Extract cycle_id
            intensity = cycle_id[:4]  # Extract the first four characters of cycle_id as intensity

            # Read data from CSV and select only the desired columns
            df = pd.read_csv(file_path, usecols=columns_to_extract)

            # Add participant ID, cycle_id, and participant_cycle_id as features
            df['Participant'] = participant
            df['Cycle_ID'] = cycle_id
            df['Participant_Cycle_ID'] = f"{participant}_{cycle_id}"
            #df['Intensity'] = intensity

            # Since Data will get shuffled (idk why but shuffling makes the model so much better.. ??)
            # So thus, need to store original index values 
            df['Original_Index'] = df.index

            # # Add normalized_cycle_position
            # df['Normalized_Cycle_Position'] = df.index / (total_data_points - 1)

            if (intensity == "HIIT"):
                df['Intensity'] = .90
            else:
                df['Intensity'] = .50
            
            # df['Intensity'] = intensity  # this is either "HIIT" or "MICT"

            data_frames.append(df)

    # Concatenate all data frames
    processed_data = pd.concat(data_frames, ignore_index=True)

    # Merge with participant weights
    weights_df = pd.read_csv("Participant Weights.csv")
    weights_df['Weight'] = weights_df['Weight'].astype(float)
    weights_df['Wingspan'] = weights_df['Wingspan'].astype(float)
    processed_data = pd.merge(processed_data, weights_df, left_on='Participant', right_on='Participant')

    return processed_data

# %%
# # Set up paths
# data_directory = "Processed Data for ML"
# output_folder = "Train and Test Data 10 Fold"

# # Read and process data
# data = read_and_process_data(data_directory)

# # Shuffle the data
# data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# # Get unique participants
# participants = data['Participant'].unique()

# # Initialize KFold cross-validator with 10 folds
# kf = KFold(n_splits=10, shuffle=True, random_state=42)

# # Create lists to store train and test sets for all folds
# all_X_train_sets = []
# all_y_train_sets = []
# all_X_test_sets = []
# all_y_test_sets = []

# fold_number = 1

# # Iterate over each fold
# for train_index, test_index in kf.split(participants):
#     train_participants = participants[train_index]
#     test_participants = participants[test_index]
    
#     # Split the data into train and test based on the selected participants
#     train_data = data[data['Participant'].isin(train_participants)]
#     test_data = data[data['Participant'].isin(test_participants)]
    
#     # Specify the output columns
#     output_columns = ['Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz']
    
#     # Create X (input) and y (output) for train/validation/test
#     X_train = train_data.drop(output_columns, axis=1)  # Dropping the output columns to create input
#     y_train = train_data[output_columns]  # Creating output, each column will be a separate y
    
#     X_test = test_data.drop(output_columns, axis=1)  # Dropping the output columns to create input
#     y_test = test_data[output_columns]  # Creating output, each column will be a separate y
    
#     # Store train and test data
#     fold_folder = os.path.join(output_folder, f"Fold_{fold_number}")
#     os.makedirs(fold_folder, exist_ok=True)
    
#     # Save train and test data to CSV
#     train_data.to_csv(os.path.join(fold_folder, "train_data.csv"), index=False)
#     test_data.to_csv(os.path.join(fold_folder, "test_data.csv"), index=False)
    
#     # Save participant numbers to text files
#     np.savetxt(os.path.join(fold_folder, "train_participants.txt"), train_participants, fmt='%d')
#     np.savetxt(os.path.join(fold_folder, "test_participants.txt"), test_participants, fmt='%d')
    
#     # Append train and test sets to lists
#     all_X_train_sets.append(X_train)
#     all_y_train_sets.append(y_train)
#     all_X_test_sets.append(X_test)
#     all_y_test_sets.append(y_test)
    
#     fold_number += 1

# %%
# Set up paths
data_directory = "Processed Data for ML"
output_folder = "Train and Test Data (Leave-One-Out) - Trial 3" # no shuffling for trial 3

# Read and process data
data = read_and_process_data(data_directory)

# Shuffle the data (optional, since the split is deterministic based on participant ID)
#data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# Get unique participants
participants = data['Participant'].unique()

# Changing the order of the participants (now we're sorting it from 1-21)
participants = np.sort(participants)

# Check that we have exactly 20 participants
assert len(participants) == 20, "The number of participants is not equal to 20."

# Create lists to store train and test sets
all_X_train_sets = []
all_y_train_sets = []
all_X_test_sets = []
all_y_test_sets = []

# Iterate over each participant to leave out
for i in range(len(participants)):
    test_participant = participants[i]  # Select the participant to leave out for testing
    train_participants = np.delete(participants, i)  # All other participants are used for training
    
    # Split the data into train and test based on the selected participants
    train_data = data[data['Participant'].isin(train_participants)]
    test_data = data[data['Participant'] == test_participant]
    
    # Specify the output columns
    output_columns = ['Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz']
    
    # Create X (input) and y (output) for train and test
    X_train = train_data.drop(output_columns, axis=1)
    y_train = train_data[output_columns]
    X_test = test_data.drop(output_columns, axis=1)
    y_test = test_data[output_columns]
    
    # Store train and test data
    fold_folder = os.path.join(output_folder, f"Fold_{i+1}")
    os.makedirs(fold_folder, exist_ok=True)
    
    # Save train and test data to CSV
    train_data.to_csv(os.path.join(fold_folder, "train_data.csv"), index=False)
    test_data.to_csv(os.path.join(fold_folder, "test_data.csv"), index=False)
    
    # Save participant numbers to text files
    np.savetxt(os.path.join(fold_folder, "train_participants.txt"), train_participants, fmt='%d')
    np.savetxt(os.path.join(fold_folder, "test_participant.txt"), [test_participant], fmt='%d')
    
    # Append train and test sets to lists
    all_X_train_sets.append(X_train)
    all_y_train_sets.append(y_train)
    all_X_test_sets.append(X_test)
    all_y_test_sets.append(y_test)

# Now you have 20 unique splits where each participant has been the test set exactly once.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import gc  # Import the garbage collector module

# Define numerical features
numeric_features = ['radius_X', 'radius_Y', 'radius_Z', 'radius_Ox', 'radius_Oy', 'radius_Oz', 'Weight', 'Wingspan', 'Intensity']
#categorical_features = ['Intensity']

# Create transformers for numerical and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Create a preprocessor that applies transformers to specific columns 
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        #('cat', categorical_transformer, categorical_features)
    ]
)

# Initialize a dictionary to store best models for each fold
best_models = {}

# Define RandomForestRegressor with n_estimators=400
regressor = RandomForestRegressor(n_estimators=300, n_jobs=-1)

# Iterate over each fold
for fold_number in range(1, 21):
    X_train = all_X_train_sets[fold_number - 1]
    y_train = all_y_train_sets[fold_number - 1]
    
    # Clear memory before starting a new fold
    gc.collect()
    
    # Create a pipeline with the preprocessor and the regressor
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', regressor)
    ])
    
    # Fit the pipeline to the training data
    pipeline.fit(X_train, y_train)
    
    # Store the best model for this output column in the corresponding fold's dictionary
    print(f"\nFold {fold_number} completed.")
    
    best_models[str(fold_number)] = pipeline
    
    # Clear memory after completing a fold
    del X_train, y_train, pipeline
    gc.collect()
# Out:
# Fold 1 completed.
#
# Fold 2 completed.
#
# Fold 3 completed.
#
# Fold 4 completed.
#
# Fold 5 completed.
#
# Fold 6 completed.
#
# Fold 7 completed.
#
# Fold 8 completed.
#
# Fold 9 completed.
#
# Fold 10 completed.
#
# Fold 11 completed.
#
# Fold 12 completed.
#
# Fold 13 completed.
#
# Fold 14 completed.
#
# Fold 15 completed.
#
# Fold 16 completed.
#
# Fold 17 completed.
#
# Fold 18 completed.
#
# Fold 19 completed.
#
# Fold 20 completed.

# %%
def calculate_mdpe_by_participant_cycle_ids(y_pred, y_test, X_test):
    """
    Calculate Median Percentage Error (MDPE) for each unique participant_cycle_id for a specific output column.
    
    Args:
    - y_pred (numpy array): Predicted values.
    - y_test (numpy array): True values.
    - X_test (DataFrame): DataFrame containing the test data including 'Participant_Cycle_ID'.
    - output_column (str): Name of the output column.
    
    Returns:
    - mdpe_scores (dict): Dictionary containing MDPE scores for each unique participant_cycle_id.
    """
    mdpe_scores = []
    
    # Get unique participant_cycle_ids
    unique_participant_cycle_ids = X_test['Participant_Cycle_ID'].unique()
    
    # Calculate MDPE for each unique participant_cycle_id
    for unique_id in unique_participant_cycle_ids:
        mask = X_test['Participant_Cycle_ID'] == unique_id
        y_pred_id = y_pred[mask]
        y_test_id = y_test[mask]
        
        # Exclude NaN values
        mask_valid = ~np.isnan(y_test_id)
        y_pred_id = y_pred_id[mask_valid]
        y_test_id = y_test_id[mask_valid]
        
        mdpe = np.median((y_pred_id - y_test_id) / y_test_id * 100)
        mdpe_scores.append(mdpe)
        
    return mdpe_scores

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Initialize y_pred as a dictionary with keys for each fold number
y_pred = {fold_number: [] for fold_number in range(1, 11)}

# Create a directory to store the y_pred for each fold and each output
# Leave-One-Out Trial 2 uses n_estimators=300 to speed up training process
output_directory = "RF Outputs (Leave One Out) - Trial 3"
os.makedirs(output_directory, exist_ok=True)

mdpe_scores_outputs = {}

# Accumulate MDPE scores across all folds for each output variable
combined_mdpe_scores = {output_col: [] for output_col in output_columns}

print(len(best_models))

# Iterate over each fold
for fold_number in range(1, 21):
    X_test = all_X_test_sets[fold_number - 1]
    y_test = all_y_test_sets[fold_number - 1]
    
    print(f"\nFold {fold_number}:")
    
    # Predict y_pred for all output columns in this fold
    y_pred[fold_number] = best_models[str(fold_number)].predict(X_test)

    # Save selected columns from X_test, y_test, and y_pred for this fold as CSV
    fold_output_directory = os.path.join(output_directory, f"Fold_{fold_number}")
    os.makedirs(fold_output_directory, exist_ok=True)

    # Convert the NumPy array to a pandas DataFrame
    y_pred_df = pd.DataFrame(y_pred[fold_number], columns=output_columns)
    
    # Save train and test data to CSV
    X_test.to_csv(os.path.join(fold_output_directory, "X_test.csv"), index=False)
    y_test.to_csv(os.path.join(fold_output_directory, "y_test.csv"), index=False)
    y_pred_df.to_csv(os.path.join(fold_output_directory, "y_pred.csv"), index=False)

    # Calculate MDPE scores for this fold and each output column
    mdpe_scores_list = []
    for i, output_col in enumerate(output_columns):
        y_pred_fold_output = y_pred[fold_number][:, i]
        
        mdpe_scores = calculate_mdpe_by_participant_cycle_ids(y_pred_fold_output, y_test[output_col], X_test)
        mdpe_scores_outputs[(fold_number, output_col)] = mdpe_scores
        mdpe_scores_list.append(pd.DataFrame({'Output': [output_col]*len(mdpe_scores), 'MDPE': mdpe_scores}))
        
        # Append MDPE scores to combined_mdpe_scores
        combined_mdpe_scores[output_col].extend(mdpe_scores)
        
        average = np.mean(mdpe_scores)
        std = np.std(mdpe_scores)
        print(f"Output Column: {output_col}")
        print("Average of MdPEs:", average)
        print("Standard Deviation of MdPEs:", std)
        
        # Save average and standard deviation of MdPEs to the output directory
        with open(os.path.join(output_directory, f"Fold_{fold_number}_mdpe_scores.txt"), 'a') as f:
            f.write(f"Output Column: {output_col}\n")
            f.write(f"Average of MdPEs: {average}\n")
            f.write(f"Standard Deviation of MdPEs: {std}\n\n")
    
    # Combine MDPE scores for all output columns in this fold
    mdpe_df = pd.concat(mdpe_scores_list)
    
    # Plot MDPE scores for this fold and all output columns
    plt.figure(figsize=(12, 8))
    sns.boxplot(x='Output', y='MDPE', data=mdpe_df, palette='husl')  # Using 'husl' palette for more colorful plots
    plt.title(f'Box-and-Whisker Plot of MDPE Scores for Fold {fold_number}')
    plt.ylabel('MDPE')
    plt.xlabel('Output Column')
    plt.xticks(rotation=45)
    plt.savefig(os.path.join(fold_output_directory, f"MDPE_plot.png"))
    plt.close()

# Calculate the mean and standard deviation of MDPE scores for each output variable across all folds
average_mdpe_scores = {}
std_mdpe_scores = {}

for output_col in output_columns:
    average_mdpe_scores[output_col] = np.mean(combined_mdpe_scores[output_col])
    std_mdpe_scores[output_col] = np.std(combined_mdpe_scores[output_col])

# Write mean and standard deviation of MDPEs to a txt file
with open(os.path.join(output_directory, "average_mdpe_scores.txt"), 'w') as f:
    for output_col in output_columns:
        f.write(f"Output Column: {output_col}\n")
        f.write(f"Average of MdPEs across 10 folds: {average_mdpe_scores[output_col]}\n")
        f.write(f"Standard Deviation of MdPEs across 10 folds: {std_mdpe_scores[output_col]}\n\n")

# Combine MDPE scores for all output columns across all folds
combined_mdpe_df = pd.concat([pd.DataFrame({'Output': [output_col]*len(combined_mdpe_scores[output_col]), 'MDPE': combined_mdpe_scores[output_col]}) for output_col in output_columns], ignore_index=True)

# Save combined MDPE scores to CSV
combined_mdpe_df.to_csv(os.path.join(output_directory, "combined_mdpe_scores.csv"), index=False)

# Plot combined MDPE scores for all output columns
plt.figure(figsize=(12, 8))
sns.boxplot(x='Output', y='MDPE', data=combined_mdpe_df, palette='husl')  # Using 'husl' palette for more colorful plots
plt.title('Box-and-Whisker Plot of Combined MDPE Scores for All Folds')
plt.ylabel('MDPE')
plt.xlabel('Output Column')
plt.xticks(rotation=45)
plt.savefig(os.path.join(output_directory, "combined_MDPE_plot.png"))
plt.close()
# Out:
# 20
#
# Fold 1:
# Output Column: Fx
# Average of MdPEs: -0.39306699826251607
# Standard Deviation of MdPEs: 0.9975994677024761
# Output Column: Fy
# Average of MdPEs: -0.2803208017489468
# Standard Deviation of MdPEs: 0.46532995781907793
# Output Column: Fz
# Average of MdPEs: -1.2259626002354143
# Standard Deviation of MdPEs: 1.8227244688925777
# Output Column: Tx
# Average of MdPEs: -0.26455657543127686
# Standard Deviation of MdPEs: 0.667153931661335
# Output Column: Ty
# Average of MdPEs: -0.38071690283180964
# Standard Deviation of MdPEs: 0.7063337905464655
# Output Column: Tz
# Average of MdPEs: -0.25808302375498593
# Standard Deviation of MdPEs: 1.6399827161542964
#
# Fold 2:
# Output Column: Fx
# Average of MdPEs: -0.10914320458250536
# Standard Deviation of MdPEs: 0.7417925741666496
# Output Column: Fy
# Average of MdPEs: -0.12760868489568297
# Standard Deviation of MdPEs: 0.37676223743929077
# Output Column: Fz
# Average of MdPEs: -1.2832776303540152
# Standard Deviation of MdPEs: 1.3421486333144104
# Output Column: Tx
# Average of MdPEs: -0.24431961276440703
# Standard Deviation of MdPEs: 0.8048374386720192
# Output Column: Ty
# Average of MdPEs: -0.0911018116460169
# Standard Deviation of MdPEs: 0.9189129778188271
# Output Column: Tz
# Average of MdPEs: 0.33980682366734066
# Standard Deviation of MdPEs: 1.390850421854148
#
# Fold 3:
# Output Column: Fx
# Average of MdPEs: -0.06997994233892321
# Standard Deviation of MdPEs: 0.3904269155337295
# Output Column: Fy
# Average of MdPEs: -0.18379962896403543
# Standard Deviation of MdPEs: 0.4423253491092993
# Output Column: Fz
# Average of MdPEs: -1.2814573768551567
# Standard Deviation of MdPEs: 1.5002299114771978
# Output Column: Tx
# Average of MdPEs: -0.1686253373550235
# Standard Deviation of MdPEs: 0.5754331176790427
# Output Column: Ty
# Average of MdPEs: -0.0935668427063386
# Standard Deviation of MdPEs: 0.41654514192355613
# Output Column: Tz
# Average of MdPEs: 0.047794405388226796
# Standard Deviation of MdPEs: 0.8302347668196745
#
# Fold 4:
# Output Column: Fx
# Average of MdPEs: -0.1388619441886969
# Standard Deviation of MdPEs: 0.8125537970320579
# Output Column: Fy
# Average of MdPEs: -0.3788863415903998
# Standard Deviation of MdPEs: 0.5700983268953064
# Output Column: Fz
# Average of MdPEs: -0.602731629794422
# Standard Deviation of MdPEs: 1.3137308604827835
# Output Column: Tx
# Average of MdPEs: -0.2813590274436111
# Standard Deviation of MdPEs: 0.8441044917193641
# Output Column: Ty
# Average of MdPEs: -0.0536790010592982
# Standard Deviation of MdPEs: 0.8637830284856209
# Output Column: Tz
# Average of MdPEs: 0.2205576422842652
# Standard Deviation of MdPEs: 1.3188657988302708
#
# Fold 5:
# Output Column: Fx
# Average of MdPEs: -0.29171913473782607
# Standard Deviation of MdPEs: 0.5240492291668322
# Output Column: Fy
# Average of MdPEs: -0.2779393424059016
# Standard Deviation of MdPEs: 0.32974389135684934
# Output Column: Fz
# Average of MdPEs: -0.7149245487943406
# Standard Deviation of MdPEs: 0.7856945021841558
# Output Column: Tx
# Average of MdPEs: -0.3799378924321047
# Standard Deviation of MdPEs: 1.0051411995631236
# Output Column: Ty
# Average of MdPEs: -0.4083321168414212
# Standard Deviation of MdPEs: 0.4190224152849301
# Output Column: Tz
# Average of MdPEs: 0.02167431154342382
# Standard Deviation of MdPEs: 1.2824805176279337
#
# Fold 6:
# Output Column: Fx
# Average of MdPEs: 0.07394684697871039
# Standard Deviation of MdPEs: 0.9001190471454672
# Output Column: Fy
# Average of MdPEs: -0.12586587522521062
# Standard Deviation of MdPEs: 0.6959684929230233
# Output Column: Fz
# Average of MdPEs: -1.9176348816340576
# Standard Deviation of MdPEs: 2.067902590215422
# Output Column: Tx
# Average of MdPEs: -0.21098835290631276
# Standard Deviation of MdPEs: 0.8295304514534172
# Output Column: Ty
# Average of MdPEs: 0.004851415062398491
# Standard Deviation of MdPEs: 0.8221878127174024
# Output Column: Tz
# Average of MdPEs: 0.7448289081640421
# Standard Deviation of MdPEs: 1.6625102006259833
#
# Fold 7:
# Output Column: Fx
# Average of MdPEs: -0.22504471775783483
# Standard Deviation of MdPEs: 0.749893124744478
# Output Column: Fy
# Average of MdPEs: -0.40059569547209684
# Standard Deviation of MdPEs: 0.8164528904135523
# Output Column: Fz
# Average of MdPEs: -1.055187492812067
# Standard Deviation of MdPEs: 2.386665396509665
# Output Column: Tx
# Average of MdPEs: -0.4327287610974773
# Standard Deviation of MdPEs: 1.0394580115616472
# Output Column: Ty
# Average of MdPEs: -0.003310864346403449
# Standard Deviation of MdPEs: 1.0253418279421813
# Output Column: Tz
# Average of MdPEs: 0.120086262594632
# Standard Deviation of MdPEs: 1.1520265045093756
#
# Fold 8:
# Output Column: Fx
# Average of MdPEs: -0.06519597085916719
# Standard Deviation of MdPEs: 1.0051541034409759
# Output Column: Fy
# Average of MdPEs: -0.17540509528417833
# Standard Deviation of MdPEs: 0.5651612530637116
# Output Column: Fz
# Average of MdPEs: -1.9778353480052935
# Standard Deviation of MdPEs: 2.134583661986611
# Output Column: Tx
# Average of MdPEs: -0.1766151309099797
# Standard Deviation of MdPEs: 0.4172034491304155
# Output Column: Ty
# Average of MdPEs: -0.210612894470116
# Standard Deviation of MdPEs: 0.9020929114211776
# Output Column: Tz
# Average of MdPEs: 0.15924220263879038
# Standard Deviation of MdPEs: 0.6061474486495206
#
# Fold 9:
# Output Column: Fx
# Average of MdPEs: -0.0389034611939124
# Standard Deviation of MdPEs: 0.5799896875284088
# Output Column: Fy
# Average of MdPEs: -0.1580180789153862
# Standard Deviation of MdPEs: 0.7667679095700607
# Output Column: Fz
# Average of MdPEs: -0.7178368008419694
# Standard Deviation of MdPEs: 0.7091422682669201
# Output Column: Tx
# Average of MdPEs: -0.18942646374882655
# Standard Deviation of MdPEs: 0.7661268776478963
# Output Column: Ty
# Average of MdPEs: -0.07726321677337156
# Standard Deviation of MdPEs: 0.5839597625430724
# Output Column: Tz
# Average of MdPEs: 0.21031696109861095
# Standard Deviation of MdPEs: 0.8796961036148432
#
# Fold 10:
# Output Column: Fx
# Average of MdPEs: -0.10816599500834567
# Standard Deviation of MdPEs: 0.45280109522283135
# Output Column: Fy
# Average of MdPEs: -0.16446627529357938
# Standard Deviation of MdPEs: 0.4170799843809765
# Output Column: Fz
# Average of MdPEs: -1.9664000972420652
# Standard Deviation of MdPEs: 2.2005944842424725
# Output Column: Tx
# Average of MdPEs: -0.25902099415043744
# Standard Deviation of MdPEs: 0.8453927698455469
# Output Column: Ty
# Average of MdPEs: -0.19214410911763444
# Standard Deviation of MdPEs: 0.7519060344028463
# Output Column: Tz
# Average of MdPEs: 0.06443833453694166
# Standard Deviation of MdPEs: 0.9523410289195915
#
# Fold 11:
# Output Column: Fx
# Average of MdPEs: -0.12538206578717118
# Standard Deviation of MdPEs: 0.4073809269950591
# Output Column: Fy
# Average of MdPEs: -0.10482065134088021
# Standard Deviation of MdPEs: 0.5422884829327085
# Output Column: Fz
# Average of MdPEs: -0.38691089856858385
# Standard Deviation of MdPEs: 3.59518716676945
# Output Column: Tx
# Average of MdPEs: -0.20686590154537443
# Standard Deviation of MdPEs: 0.7774513833104116
# Output Column: Ty
# Average of MdPEs: -0.24255036404092079
# Standard Deviation of MdPEs: 0.5191391087095208
# Output Column: Tz
# Average of MdPEs: 0.12296803081447877
# Standard Deviation of MdPEs: 1.0057684412223502
#
# Fold 12:
# Output Column: Fx
# Average of MdPEs: -0.05669522929014795
# Standard Deviation of MdPEs: 0.76530252780071
# Output Column: Fy
# Average of MdPEs: -0.016004449040439104
# Standard Deviation of MdPEs: 0.39992977615301767
# Output Column: Fz
# Average of MdPEs: -0.660066925716614
# Standard Deviation of MdPEs: 1.1762480763726029
# Output Column: Tx
# Average of MdPEs: -0.06547747160248106
# Standard Deviation of MdPEs: 0.4506443624654458
# Output Column: Ty
# Average of MdPEs: -0.10625537692703506
# Standard Deviation of MdPEs: 0.7636071145336153
# Output Column: Tz
# Average of MdPEs: -0.05445335797638178
# Standard Deviation of MdPEs: 0.9730080796432855
#
# Fold 13:
# Output Column: Fx
# Average of MdPEs: -0.0654171978976045
# Standard Deviation of MdPEs: 0.36417515833657316
# Output Column: Fy
# Average of MdPEs: -0.0013051365191456565
# Standard Deviation of MdPEs: 0.43329260306664674
# Output Column: Fz
# Average of MdPEs: -0.3097964588671313
# Standard Deviation of MdPEs: 0.9080504920460996
# Output Column: Tx
# Average of MdPEs: -0.20678797714384525
# Standard Deviation of MdPEs: 0.41196339607346527
# Output Column: Ty
# Average of MdPEs: -0.03830784953791215
# Standard Deviation of MdPEs: 0.4165287451169787
# Output Column: Tz
# Average of MdPEs: 0.06127022477439196
# Standard Deviation of MdPEs: 0.9277875242766056
#
# Fold 14:
# Output Column: Fx
# Average of MdPEs: -0.11280901381101503
# Standard Deviation of MdPEs: 0.6711965206956995
# Output Column: Fy
# Average of MdPEs: -0.19316787663782584
# Standard Deviation of MdPEs: 0.9398409437186712
# Output Column: Fz
# Average of MdPEs: -0.54458558595669
# Standard Deviation of MdPEs: 2.0174755866051144
# Output Column: Tx
# Average of MdPEs: -0.16822713440613293
# Standard Deviation of MdPEs: 1.25276309218883
# Output Column: Ty
# Average of MdPEs: -0.1268642616216263
# Standard Deviation of MdPEs: 0.7633621983807777
# Output Column: Tz
# Average of MdPEs: -0.20490634120090787
# Standard Deviation of MdPEs: 1.075810062957654
#
# Fold 15:
# Output Column: Fx
# Average of MdPEs: -0.09105383361030855
# Standard Deviation of MdPEs: 0.2718606027126324
# Output Column: Fy
# Average of MdPEs: -0.20923560288371224
# Standard Deviation of MdPEs: 0.6636477470084061
# Output Column: Fz
# Average of MdPEs: -0.16329625943497486
# Standard Deviation of MdPEs: 1.207098295926611
# Output Column: Tx
# Average of MdPEs: -0.35860631975893403
# Standard Deviation of MdPEs: 0.5288492556237463
# Output Column: Ty
# Average of MdPEs: -0.23635145253235898
# Standard Deviation of MdPEs: 0.30385510390017884
# Output Column: Tz
# Average of MdPEs: 0.2152836445683586
# Standard Deviation of MdPEs: 1.146881114463114
#
# Fold 16:
# Output Column: Fx
# Average of MdPEs: -0.0460246559245183
# Standard Deviation of MdPEs: 0.3422133313568275
# Output Column: Fy
# Average of MdPEs: -0.15291710479575454
# Standard Deviation of MdPEs: 0.30477245544831344
# Output Column: Fz
# Average of MdPEs: -0.6138231887949549
# Standard Deviation of MdPEs: 0.7244627282183139
# Output Column: Tx
# Average of MdPEs: -0.1639022426202366
# Standard Deviation of MdPEs: 0.36585820561282245
# Output Column: Ty
# Average of MdPEs: -0.10643439094928243
# Standard Deviation of MdPEs: 0.37355626751965654
# Output Column: Tz
# Average of MdPEs: -0.06795558582468435
# Standard Deviation of MdPEs: 0.7434468606529628
#
# Fold 17:
# Output Column: Fx
# Average of MdPEs: -0.15904068345574174
# Standard Deviation of MdPEs: 0.5394399478539363
# Output Column: Fy
# Average of MdPEs: -0.1288938108755439
# Standard Deviation of MdPEs: 0.4144505379777681
# Output Column: Fz
# Average of MdPEs: -0.32668606614592643
# Standard Deviation of MdPEs: 0.6868986454915642
# Output Column: Tx
# Average of MdPEs: -0.15439715621686978
# Standard Deviation of MdPEs: 0.42250636662076263
# Output Column: Ty
# Average of MdPEs: -0.34564810158145387
# Standard Deviation of MdPEs: 0.9618164043846017
# Output Column: Tz
# Average of MdPEs: -0.023287423170298093
# Standard Deviation of MdPEs: 0.853118216830582
#
# Fold 18:
# Output Column: Fx
# Average of MdPEs: -0.08467207239106356
# Standard Deviation of MdPEs: 0.7928723806055533
# Output Column: Fy
# Average of MdPEs: -0.010422029464570678
# Standard Deviation of MdPEs: 0.43928239424531335
# Output Column: Fz
# Average of MdPEs: -0.3290498519080846
# Standard Deviation of MdPEs: 2.5839049806608294
# Output Column: Tx
# Average of MdPEs: -0.15156883664770082
# Standard Deviation of MdPEs: 0.5468446808592317
# Output Column: Ty
# Average of MdPEs: -0.07941389618624144
# Standard Deviation of MdPEs: 0.894247211645922
# Output Column: Tz
# Average of MdPEs: 0.039469596321306054
# Standard Deviation of MdPEs: 1.0905721890801727
#
# Fold 19:
# Output Column: Fx
# Average of MdPEs: -0.15702817863435817
# Standard Deviation of MdPEs: 0.3169282252014121
# Output Column: Fy
# Average of MdPEs: -0.11901211768549813
# Standard Deviation of MdPEs: 0.502469726847576
# Output Column: Fz
# Average of MdPEs: -0.9241635625454115
# Standard Deviation of MdPEs: 1.252584591894072
# Output Column: Tx
# Average of MdPEs: 0.342360963310792
# Standard Deviation of MdPEs: 1.4446908212850322
# Output Column: Ty
# Average of MdPEs: 0.10143786014788314
# Standard Deviation of MdPEs: 0.8339033446417979
# Output Column: Tz
# Average of MdPEs: 0.8397703824264361
# Standard Deviation of MdPEs: 2.4606830898967704
#
# Fold 20:
# Output Column: Fx
# Average of MdPEs: -8.791039854357866
# Standard Deviation of MdPEs: 8.068199584662812
# Output Column: Fy
# Average of MdPEs: -22.34356554342034
# Standard Deviation of MdPEs: 11.280578430991769
# Output Column: Fz
# Average of MdPEs: -75.1622524216239
# Standard Deviation of MdPEs: 82.06548654194665
# Output Column: Tx
# Average of MdPEs: -35.781106337675915
# Standard Deviation of MdPEs: 11.775033674396676
# Output Column: Ty
# Average of MdPEs: -21.5030298354182
# Standard Deviation of MdPEs: 6.051327737779648
# Output Column: Tz
# Average of MdPEs: -39.40564618113389
# Standard Deviation of MdPEs: 7.472692617637449

# %%
# Iterate over each fold
for fold_number, model in best_models.items():
    print(f"\nFeature importances for Fold {fold_number}:")
    
    # Extract preprocessor and regressor from the pipeline
    preprocessor = model.named_steps['preprocessor']
    regressor = model.named_steps['regressor']
    
    # Get feature names after preprocessing
    feature_names = preprocessor.transformers_[0][2]  # Numeric feature names
    
    # Get feature importances
    feature_importances = regressor.feature_importances_
    
    # Sort indices by importance
    sorted_indices = np.argsort(feature_importances)[::-1]
    
    # Print feature importances
    for idx in sorted_indices:
        print(f"Feature {feature_names[idx]}: {feature_importances[idx]}")
# Out:
# Feature importances for Fold 1:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 2:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 3:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 4:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 5:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 6:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 7:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 8:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 9:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
#
# Feature importances for Fold 10:
# Feature radius_Y: 0.4040274506143981
# Feature radius_Z: 0.17633295262248772
# Feature radius_X: 0.1234071712955904
# Feature radius_Oz: 0.06396941662427019
# Feature Wingspan: 0.06033231668958058
# Feature radius_Oy: 0.05826119720932006
# Feature Weight: 0.05278096738338877
# Feature Intensity: 0.03825593825609863
# Feature radius_Ox: 0.02263258930486569
